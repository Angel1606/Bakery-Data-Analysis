# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
file_path = r'C:\Users\HP\OneDrive\Desktop\Python project\Bakery Sales Data.csv'
df = pd.read_csv(file_path, encoding='unicode_escape')

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.head()
# Out:
#    User_ID Customer_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002340         James  P00119642      F     36-45   39               1
# 1  1005664          Dean  P00111642      F     18-25   20               0
# 2  1002523          Aman  P00293342      F     26-35   32               1
# 3  1002503        Mousam  P00220042      F     36-45   36               0
# 4  1002638        Damala  P00346242      F     26-35   35               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0  Andhra Pradesh  Southern         Aviation             Auto       3
# 1  Andhra Pradesh  Southern         Aviation             Auto       2
# 2  Andhra Pradesh  Southern  Food Processing             Auto       3
# 3  Andhra Pradesh  Southern       Automobile             Auto       2
# 4     Maharashtra   Western            Media             Auto       2
#
#     Amount  Status  Review
# 0  23389.0     NaN     NaN
# 1  23365.0     NaN     NaN
# 2  23326.0     NaN     NaN
# 3  23314.0     NaN     NaN
# 4  23306.0     NaN     NaN

# %%
#data cleaning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           10000 non-null  int64
#  1   Customer_name     10000 non-null  object
#  2   Product_ID        10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age Group         10000 non-null  object
#  5   Age               10000 non-null  int64
#  6   Marital_Status    10000 non-null  int64
#  7   State             10000 non-null  object
#  8   Zone              10000 non-null  object
#  9   Occupation        10000 non-null  object
#  10  Product_Category  10000 non-null  object
#  11  Orders            10000 non-null  int64
#  12  Amount            9991 non-null   float64
#  13  Status            0 non-null      float64
#  14  Review            0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#drop unrelated/blank columns
df.drop(['Status', 'Review'], axis=1, inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID             0
# Customer_name       0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              9
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
# change data type
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
df.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#       User_ID Customer_name Product_ID Gender Age Group  Age  Shaadi  \
# 0     1002340         James  P00119642      F     36-45   39       1
# 1     1005664          Dean  P00111642      F     18-25   20       0
# 2     1002523          Aman  P00293342      F     26-35   32       1
# 3     1002503        Mousam  P00220042      F     36-45   36       0
# 4     1002638        Damala  P00346242      F     26-35   35       1
# ...       ...           ...        ...    ...       ...  ...     ...
# 9995  1001587       Suzanne  P00174442      M     26-35   26       1
# 9996  1003203          Ryan  P00224742      F     36-45   43       0
# 9997  1004277        Sanjay  P00038342      F     36-45   41       1
# 9998  1004150         Harry  P00190242      F     26-35   35       0
# 9999  1002840        Justin  P00195342      F     26-35   31       0
#
#                State      Zone       Occupation    Product_Category  Orders  \
# 0     Andhra Pradesh  Southern         Aviation                Auto       3
# 1     Andhra Pradesh  Southern         Aviation                Auto       2
# 2     Andhra Pradesh  Southern  Food Processing                Auto       3
# 3     Andhra Pradesh  Southern       Automobile                Auto       2
# 4        Maharashtra   Western            Media                Auto       2
# ...              ...       ...              ...                 ...     ...
# 9995   Uttar Pradesh   Central       Healthcare  Clothing & Apparel       2
# 9996       Karnataka  Southern         Aviation            Pet Care       1
# 9997   Uttar Pradesh   Central         Aviation  Clothing & Apparel       3
# 9998  Andhra Pradesh  Southern          Banking  Clothing & Apparel       2
# 9999   Uttar Pradesh   Central        IT Sector            Pet Care       3
#
#       Amount
# 0      23389
# 1      23365
# 2      23326
# 3      23314
# 4      23306
# ...      ...
# 9995    3507
# 9996    3506
# 9997    3506
# 9998    3505
# 9999    3505
#
# [9991 rows x 13 columns]

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID          Age  Marital_Status       Orders        Amount
# count  9.991000e+03  9991.000000     9991.000000  9991.000000   9991.000000
# mean   1.003008e+06    35.575518        0.417175     2.486338  10302.565109
# std    1.715602e+03    12.798167        0.493117     1.115272   4788.602875
# min    1.000001e+06    12.000000        0.000000     1.000000   3505.000000
# 25%    1.001495e+06    27.000000        0.000000     1.000000   6911.000000
# 50%    1.003065e+06    33.000000        0.000000     2.000000   8717.000000
# 75%    1.004434e+06    43.000000        1.000000     3.000000  13349.500000
# max    1.006040e+06    92.000000        1.000000     4.000000  23389.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                Age       Orders        Amount
# count  9991.000000  9991.000000   9991.000000
# mean     35.575518     2.486338  10302.565109
# std      12.798167     1.115272   4788.602875
# min      12.000000     1.000000   3505.000000
# 25%      27.000000     1.000000   6911.000000
# 50%      33.000000     2.000000   8717.000000
# 75%      43.000000     3.000000  13349.500000
# max      92.000000     4.000000  23389.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)
    # hue segregates on basis of gender

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <AxesSubplot: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <AxesSubplot: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <AxesSubplot: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <AxesSubplot: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <AxesSubplot: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <AxesSubplot: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Product_ID'>

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# Unmarried women of the age group 26-35 yrs from Uttar Pradesh, working in IT are more likely to buy most of the products.
#
# Products of the category food are most likely to be sold.
